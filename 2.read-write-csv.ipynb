# %%
spark

# %%
df = spark.read \
    .option("header", True) \
    .option("infershcema", True) \
    .csv("/Volumes/workspace/default/raw-data/orders.csv")
df.display()

# %% [markdown]
# ## writing in parquet format

# %%
df.write.mode('overwrite').parquet("/Volumes/workspace/default/raw-data/orders.parquet")
